# %% [markdown]
# # Exploring and preparing the data

# %% [markdown]
# ## 1. Dataset: BICIMAD. Details of the electric bicycle routes

# %% [markdown]
# For the development of the project we will use the data provided by the Community of Madrid in its [open data portal](https://opendata.emtmadrid.es/Datos-estaticos/Datos-generales-(1)).
#
# They provide one file per month in a json format, and each file contains one row per trip.

# %% [markdown]
# ### 1.1. Data presentation

# %% [markdown]
# Each of the files has the following columns:

# %% [markdown]
# **__id**: identificator of the movement
#
# **user_day_code**: user code. For a same date, all the movement of the sale user have the same code.
#
# **idunplug_station**: number of the origin station
#
# **idunplug_base**: number of origin base
#
# **idplug_station**: number of destination station
#
# **idplug_base**: number of destionation base
#
# **unplug_hourTime**: time the bicycle is picked up
#
# **travel_time**: time in seconds of the ride
#
# **track**: detail of the ride (GeoJSON)
#
# **user_type**: type of user:
#
#     - 0: not defined
#     - 1: anual user
#     - 2: ocasional user
#     - 3: worker of bicimad
#
# **ageRange**: age range of the user:
#
#     - 0: not defined
#     - 1: between 0 and 16 years
#     - 2: between 17 and 18 years
#     - 3: between 19 and 26 years
#     - 4: between 27 and 40 years
#     - 5: between 41 and 65 years
#     - 6: more than 65 years
#
# **zip_code**: postal code of the user

# %% [markdown]
# ### 1.2. Merging all data into a dataframe

# %%
#libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# The files used take up a lot of space, **The process of reading and merging all dataframes may take long (around 20 minutes).**

# %%
#First we create one dataframe per file
movements_january_19=pd.read_json('201901_Usage_Bicimad.json', lines=True)
movements_february_19=pd.read_json('201902_Usage_Bicimad.json', lines=True)
movements_march_19=pd.read_json('201903_Usage_Bicimad.json', lines=True)
movements_april_19=pd.read_json('201904_Usage_Bicimad.json', lines=True)
movements_may_19=pd.read_json('201905_Usage_Bicimad.json', lines=True)
movements_june_19=pd.read_json('201906_Usage_Bicimad.json', lines=True)

# %%
movements_july_19=pd.read_json('201907_movements.json', lines=True)
movements_august_19=pd.read_json('201908_movements.json', lines=True)
movements_september_19=pd.read_json('201909_movements.json', lines=True)
movements_october_19=pd.read_json('201910_movements.json', lines=True)
movements_november_19=pd.read_json('201911_movements.json', lines=True)
movements_december_19=pd.read_json('201912_movements.json', lines=True)
movements_january_20=pd.read_json('202001_movements.json', lines=True)
movements_february_20=pd.read_json('202002_movements.json', lines=True)
movements_march_20=pd.read_json('202003_movements.json', lines=True)
movements_april_20=pd.read_json('202004_movements.json', lines=True)
movements_may_20=pd.read_json('202005_movements.json', lines=True)
movements_june_20=pd.read_json('202006_movements.json', lines=True)
movements_july_20=pd.read_json('202007_movements.json', lines=True)
movements_august_20=pd.read_json('202008_movements.json', lines=True)
movements_september_20=pd.read_json('202009_movements.json', lines=True)
movements_october_20=pd.read_json('202010_movements.json', lines=True)
movements_november_20=pd.read_json('202011_movements.json', lines=True)
movements_december_20=pd.read_json('202012_movements.json', lines=True)
movements_january_21=pd.read_json('202101_movements.json', lines=True)
movements_february_21=pd.read_json('202102_movements.json', lines=True)
movements_march_21=pd.read_json('202103_movements.json', lines=True)
movements_april_21=pd.read_json('202104_movements.json', lines=True)
movements_may_21=pd.read_json('202105_movements.json', lines=True)
movements_june_21=pd.read_json('202106_movements.json', lines=True)

# %% [markdown]
# There are two types of files, these are distinguished because they have different formats in the unplug hour time column, the files before July 2019 have the column in dictionary format and the files after July 2019 have the column in timestamp UTC format.
#
# Before merging all the dataframes we are going to treat both cases separately, and convert the column ``unplug_hourTime`` into a datetime format (datetime64[ns]).

# %%
movements_january_19['unplug_hourTime']
# Out:
# 0         {'$date': '2019-01-01T00:00:00.000+0100'}
# 1         {'$date': '2019-01-01T00:00:00.000+0100'}
# 2         {'$date': '2019-01-01T00:00:00.000+0100'}
# 3         {'$date': '2019-01-01T00:00:00.000+0100'}
# 4         {'$date': '2019-01-01T00:00:00.000+0100'}
#                             ...
# 279218    {'$date': '2019-02-01T00:00:00.000+0100'}
# 279219    {'$date': '2019-02-01T00:00:00.000+0100'}
# 279220    {'$date': '2019-02-01T00:00:00.000+0100'}
# 279221    {'$date': '2019-02-01T00:00:00.000+0100'}
# 279222    {'$date': '2019-02-01T00:00:00.000+0100'}
# Name: unplug_hourTime, Length: 279223, dtype: object

# %%
movements_january_19['unplug_hourTime'] = movements_january_19['unplug_hourTime'].str['$date']
movements_february_19['unplug_hourTime'] = movements_february_19['unplug_hourTime'].str['$date']
movements_march_19['unplug_hourTime'] = movements_march_19['unplug_hourTime'].str['$date']
movements_april_19['unplug_hourTime'] = movements_april_19['unplug_hourTime'].str['$date']
movements_may_19['unplug_hourTime'] = movements_may_19['unplug_hourTime'].str['$date']
movements_june_19['unplug_hourTime'] = movements_june_19['unplug_hourTime'].str['$date']

# %%
#dataframe with journeys before july 2019
movements_1= movements_january_19.append(movements_february_19).append(movements_march_19).append(movements_april_19).append(movements_may_19).append(movements_june_19)

# %%
#dataframe with journeys after july 2019
movements = movements_july_19.append(movements_august_19).append(movements_september_19).append(movements_october_19).append(movements_november_19).append(movements_december_19).append(movements_january_20).append(movements_february_20).append(movements_march_20).append(movements_april_20).append(movements_may_20).append(movements_june_20).append(movements_july_20).append(movements_august_20).append(movements_september_20).append(movements_october_20).append(movements_november_20).append(movements_december_20).append(movements_january_21).append(movements_february_21).append(movements_march_21).append(movements_april_21).append(movements_may_21).append(movements_june_21)

# %% [markdown]
# Now we are going to extract useful columns of time, that we will use to better understand the evolution of demand

# %%
movements['datetime'] = pd.to_datetime(movements['unplug_hourTime'])
movements['date'] = movements['datetime'].dt.date
movements['weekday'] = movements['datetime'].dt.day_name()
movements['hour'] = movements['datetime'].dt.hour
movements['month'] = movements['datetime'].dt.month
movements['year'] = movements['datetime'].dt.year
movements['day'] = movements['datetime'].dt.day
movements['time'] = movements['datetime'].dt.time
movements['datetime'] = movements['datetime'].dt.tz_localize(None)

# %%
movements_1['datetime'] = pd.to_datetime(movements_1['unplug_hourTime'], utc=True)
movements_1['date'] = movements_1['datetime'].dt.date
movements_1['weekday'] = movements_1['datetime'].dt.day_name()
movements_1['hour'] = movements_1['datetime'].dt.hour
movements_1['month'] = movements_1['datetime'].dt.month
movements_1['year'] = movements_1['datetime'].dt.year
movements_1['day'] = movements_1['datetime'].dt.day
movements_1['time'] = movements_1['datetime'].dt.time
movements_1['datetime'] = movements_1['datetime'].dt.tz_localize(None)

# %%
#We merge both dataframes 
movements = movements_1.append(movements)

# %%
movements.columns
# Out:
# Index(['_id', 'user_day_code', 'idplug_base', 'track', 'user_type',
#        'idunplug_base', 'travel_time', 'idunplug_station', 'ageRange',
#        'idplug_station', 'unplug_hourTime', 'zip_code', 'datetime', 'date',
#        'weekday', 'hour', 'month', 'year', 'day', 'time'],
#       dtype='object')

# %%
#We only keep the columns we are interested
movements = movements[['user_type','travel_time', 'idunplug_station','ageRange', 'idplug_station',  'zip_code', 'datetime', 'date',
       'weekday', 'hour', 'month', 'year', 'day', 'time']]

# %% [markdown]
# ### 1.3. Cleaning and preparing dataframe

# %% [markdown]
# We are interested in predicting the demand, so we remove for the dataframe we just created all the trips made by workers of bicimad (user_type = 3)

# %%
movements = movements[movements['user_type'] != 3]

# %% [markdown]
# We are going to remove all the trips whose duration is less than 2 minutes and more than 4 hours, considering that these trips are wrong in the table due to errors in the data collection or technical failures of the bycicles

# %%
movements['travel_time'] = movements['travel_time'] /60
movements = movements[(movements['travel_time']>=2) & (movements['travel_time'] < 240)]
# Out:
# <ipython-input-17-0ba96135ecd4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movements['travel_time'] = movements['travel_time'] /60

# %% [markdown]
# Now we are going to explore the data to check the existance of NaN in the columns.
# For doing this we are going to use the library missing no

# %%
#pip install missingno
import missingno

missingno.matrix(movements)
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the plot above we can see that there are no NaN in our dataframe.

# %% [markdown]
# Now we are going to check the format of the columns

# %%
movements.dtypes
# Out:
# user_type                    int64
# travel_time                float64
# idunplug_station             int64
# ageRange                     int64
# idplug_station               int64
# zip_code                    object
# datetime            datetime64[ns]
# date                        object
# weekday                     object
# hour                         int64
# month                        int64
# year                         int64
# day                          int64
# time                        object
# dtype: object

# %% [markdown]
# ## 2. Dataset: Stations. Information about stations

# %% [markdown]
# We are interested in predicting the demand of bicycles per area. In the dataframe of movements we have the information about the unplug station, so we need to merge that information with all the information of the station.
#
# The data of the stations is obtained from the [open data portal of the Community of Madrid](https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=f4b07e0543815610VgnVCM1000001d4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default)

# %% [markdown]
# The dataset contains the following columns:
#
# **id**: code of the base station
#
# **latitude**: latitude of the station in WGS84 format
#
# **longitude**: lenght of the station in WGS84 format
#
# **name**: name of the station
#
# **light**: ocupation of the station:
#
#     - 0: low
#     - 1: medium
#     - 2: high
#     - 3: inactive
#
# **number**: logical designation of the Base Station
#
# **activate**: active station
#     - 0: not active
#     - 1: active
#
# **no_available**: station availability
#     - 0: available
#     - 1: unavailable
#
# **total_bases**: number of bases of the station
#
# **dock_bikes**: number of docked bicycles
#
# **free_bases**: number of free bases
#
# **reservations_count**: number of active reservations

# %% [markdown]
# From this dataset we are interested in obtaining the name and coordinates of the stations, the address and the total bases available

# %%
stations = pd.read_json('202106.json', lines=True)
stations.head()
# Out:
#                           _id  \
# 0  2021-06-01T00:43:39.688214
# 1  2021-06-01T01:43:41.872092
# 2  2021-06-01T02:43:42.969250
# 3  2021-06-01T03:43:44.600717
# 4  2021-06-01T04:43:45.629938
#
#                                             stations
# 0  [{'activate': 1, 'name': 'Puerta del Sol A', '...
# 1  [{'activate': 1, 'name': 'Puerta del Sol A', '...
# 2  [{'activate': 1, 'name': 'Puerta del Sol A', '...
# 3  [{'activate': 1, 'name': 'Puerta del Sol A', '...
# 4  [{'activate': 1, 'name': 'Puerta del Sol A', '...

# %% [markdown]
# We want to know the number of total bases available in each stations and the information about the latitude and longitude of them, so we can consider only the first row of the file, because the information we are looking for not depend of the hour and day

# %%
stations = stations['stations'][711]
stations = pd.DataFrame(stations)

# %%
#We select the columns we are interested in 
stations = stations[['name', 'longitude', 'latitude', 'address', 'total_bases', 'id', 'number']]

# %%
stations.to_csv("all_stations.csv")

# %% [markdown]
# We are going to check if there are duplicated rows.

# %%
#Check if there are duplicated stations
sum(stations.duplicated())
# Out:
# 0

# %% [markdown]
# ## 3. Dataset: Holidays

# %% [markdown]
# We are going to add useful information for the predictive models. One of the important is the type of day (holiday, working day, weekend).
#
# We use a dataframe obtained from the [open data portal of the community of madrid.](https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=9f710c96da3f9510VgnVCM2000001f4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default)

# %%
holidays_df = pd.read_csv('calendario.csv', sep=';', names=(['day', 'day_week', 'holiday', 'type', 'festivity']))

# %% [markdown]
# We are only interested in the information of the months and year when we have the data available. So we are going to filter the dataframe to obtain the calendar from 2018 on.

# %%
holidays_df
# Out:
#              day    day_week                                holiday  \
# 0            Día  Día_semana  laborable / festivo / domingo festivo
# 1     01/01/2013      martes                                festivo
# 2     02/01/2013   miércoles                              laborable
# 3     03/01/2013      jueves                              laborable
# 4     04/01/2013     viernes                              laborable
# ...          ...         ...                                    ...
# 3647  27/12/2022      martes                                    NaN
# 3648  28/12/2022   miércoles                                    NaN
# 3649  29/12/2022      jueves                                    NaN
# 3650  30/12/2022     viernes                                    NaN
# 3651  31/12/2022      sábado                                    NaN
#
#                   type   festivity
# 0      Tipo de Festivo  Festividad
# 1     Festivo nacional   Año Nuevo
# 2                  NaN         NaN
# 3                  NaN         NaN
# 4                  NaN         NaN
# ...                ...         ...
# 3647               NaN         NaN
# 3648               NaN         NaN
# 3649               NaN         NaN
# 3650               NaN         NaN
# 3651               NaN         NaN
#
# [3652 rows x 5 columns]

# %%
holidays_df['festivity'].unique()
# Out:
# array(['Festividad', 'Año Nuevo', nan, 'Traslado Epifanía del Señor',
#        'Traslado San Jose', 'Jueves Santo', 'Viernes Santo',
#        'Fiesta del Trabajo',
#        'Dos de Mayo. Fiesta de la Comunidad de Madrid',
#        'San Isidro Labrador', 'Asuncion de la Virgen',
#        'Fiesta Nacional de Espania', 'Todos los Santos',
#        'Ntra. Sra. de la Almudena. Patrona de la ciudad',
#        'Día de la Constitucion', 'Inmaculada Concepcion',
#        'Natividad del Señor', 'Epifanía del Señor', 'Corpus Christi',
#        'Fiesta Nacional de España',
#        'Traslado Ntra. Sra. de la Almudena. Patrona de la ciudad',
#        'San Jose', 'Traslado San Isidro Labrador', 'Santiago Apostol',
#        'Traslado Natividad del Señor',
#        'Traslado de la festividad de San Jose',
#        'Traslado de la Epifanía del Señor',
#        'Día de la Constitucion Española',
#        'Traslado de la Inmaculada Concepción',
#        'Día de la Comunidad de Madrid', 'Asunción de la Virgen',
#        'Traslado del día de Todos los Santos',
#        'Nuestra Señora de la Almudena',
#        'Traslado del día de la Constitución Española', 'San José',
#        ' Día de Todos los Santos', ' Día de la Constitución Española',
#        'Traslado de la festividad de San Isidro Labrador',
#        'Santiago Apóstol', 'Nuesta Señora de la Almudena',
#        'Día de la Constitución Española',
#        'Traslado del descanso del 25 de diciembre, Natividad del Señor'],
#       dtype=object)

# %%
holidays_df['holiday'].unique()
# Out:
# array(['laborable / festivo / domingo festivo', 'festivo', 'laborable',
#        'sábado', 'domingo', nan, 'Festivo'], dtype=object)

# %%
#We are only interested in knowing the holidays
holidays_df = holidays_df[(holidays_df['holiday']=='festivo') | (holidays_df['holiday']=='Festivo') ]

# %%
#We create the columns date, so it has the same format as the movements dataframe, so we can perform the join
holidays_df['date'] = pd.to_datetime(holidays_df['day'], dayfirst=True)
holidays_df
# Out:
# <ipython-input-31-eb762b087184>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   holidays_df['date'] = pd.to_datetime(holidays_df['day'], dayfirst=True)
#              day   day_week  holiday                               type  \
# 1     01/01/2013     martes  festivo                   Festivo nacional
# 7     07/01/2013      lunes  festivo                   Festivo nacional
# 77    18/03/2013      lunes  festivo  Festivo de la Comunidad de Madrid
# 87    28/03/2013     jueves  festivo  Festivo de la comunidad de Madrid
# 88    29/03/2013    viernes  festivo                   Festivo nacional
# ...          ...        ...      ...                                ...
# 3591  01/11/2022     martes  Festivo                   Festivo nacional
# 3599  09/11/2022  miércoles  Festivo                      Festivo local
# 3626  06/12/2022     martes  Festivo                   Festivo nacional
# 3628  08/12/2022     jueves  Festivo                   Festivo nacional
# 3646  26/12/2022      lunes  Festivo                   Festivo nacional
#
#                                               festivity       date
# 1                                             Año Nuevo 2013-01-01
# 7                           Traslado Epifanía del Señor 2013-01-07
# 77                                    Traslado San Jose 2013-03-18
# 87                                         Jueves Santo 2013-03-28
# 88                                        Viernes Santo 2013-03-29
# ...                                                 ...        ...
# 3591                                   Todos los Santos 2022-11-01
# 3599                       Nuesta Señora de la Almudena 2022-11-09
# 3626                    Día de la Constitución Española 2022-12-06
# 3628                              Inmaculada Concepcion 2022-12-08
# 3646  Traslado del descanso del 25 de diciembre, Nat... 2022-12-26
#
# [145 rows x 6 columns]

# %% [markdown]
# # 4. Grouping the dataframe and making final dataset

# %% [markdown]
# We are interested in analyze and predict the demand per hour of the service of Bicimad, so we are going to group the data frame. The target variable is the number of rides per hour, in the dataframe each line represents one movement, so we are going to perform a count of the _id column (movements) to get the number of rides per hour

# %%
movements
# Out:
#         user_type  travel_time  idunplug_station  ageRange  idplug_station  \
# 0               1     2.700000                82         0              83
# 1               1     6.916667               133         5              36
# 2               1     9.083333                25         0              90
# 3               1     6.950000               105         3             155
# 4               1     7.466667                51         4              44
# ...           ...          ...               ...       ...             ...
# 413359          1    14.016667               132         5             265
# 413360          1    24.666667               182         5             265
# 413361          1    12.700000                15         5             265
# 413365          1    12.433333               234         0              84
# 413369          1    11.066667                48         5              59
#
#        zip_code            datetime        date    weekday  hour  month  year  \
# 0               2018-12-31 23:00:00  2018-12-31     Monday    23     12  2018
# 1         28005 2018-12-31 23:00:00  2018-12-31     Monday    23     12  2018
# 2               2018-12-31 23:00:00  2018-12-31     Monday    23     12  2018
# 3         28009 2018-12-31 23:00:00  2018-12-31     Monday    23     12  2018
# 4         28005 2018-12-31 23:00:00  2018-12-31     Monday    23     12  2018
# ...         ...                 ...         ...        ...   ...    ...   ...
# 413359    28020 2021-06-30 23:00:00  2021-06-30  Wednesday    23      6  2021
# 413360    28005 2021-06-30 21:00:00  2021-06-30  Wednesday    21      6  2021
# 413361    28791 2021-06-29 18:00:00  2021-06-29    Tuesday    18      6  2021
# 413365          2021-06-27 19:00:00  2021-06-27     Sunday    19      6  2021
# 413369    28007 2021-06-29 13:00:00  2021-06-29    Tuesday    13      6  2021
#
#         day      time
# 0        31  23:00:00
# 1        31  23:00:00
# 2        31  23:00:00
# 3        31  23:00:00
# 4        31  23:00:00
# ...     ...       ...
# 413359   30  23:00:00
# 413360   30  21:00:00
# 413361   29  18:00:00
# 413365   27  19:00:00
# 413369   29  13:00:00
#
# [8699458 rows x 14 columns]

# %% [markdown]
# ### 4.1. Dataframe with all the rides (all stations merged)

# %%
df_movements = movements.groupby(['date', 'weekday', 'hour', 'month', 'year', 'day', 'time','datetime']).idunplug_station.count().reset_index()

# %%
df_movements['rides'] = df_movements['idunplug_station']
df_movements = df_movements[['datetime', 'rides']]

# %%
df_movements['date'] = df_movements['datetime'].dt.date
df_movements['weekday'] = df_movements['datetime'].dt.day_name()
df_movements['hour'] = df_movements['datetime'].dt.hour
df_movements['month'] = df_movements['datetime'].dt.month
df_movements['year'] = df_movements['datetime'].dt.year
df_movements['day'] = df_movements['datetime'].dt.day
df_movements['time'] = df_movements['datetime'].dt.time

# %% [markdown]
# We are going to perform a resample, to fill all the values that have no rides in our dataframe

# %%
df_movements.set_index('datetime',inplace=True)
df_movements.sort_index(inplace=True)
df_movements_resampled = df_movements.resample('1H').sum()
df_movements_resampled
# Out:
#                      rides  hour  month  year  day
# datetime
# 2018-12-31 23:00:00    176    23     12  2018   31
# 2019-01-01 00:00:00    254     0      1  2019    1
# 2019-01-01 01:00:00    169     1      1  2019    1
# 2019-01-01 02:00:00    105     2      1  2019    1
# 2019-01-01 03:00:00     83     3      1  2019    1
# ...                    ...   ...    ...   ...  ...
# 2021-06-30 19:00:00    813    19      6  2021   30
# 2021-06-30 20:00:00    552    20      6  2021   30
# 2021-06-30 21:00:00    571    21      6  2021   30
# 2021-06-30 22:00:00    499    22      6  2021   30
# 2021-06-30 23:00:00    264    23      6  2021   30
#
# [21889 rows x 5 columns]

# %%
#With the resampling we added 1864 rows 
len(df_movements_resampled) - len(df_movements)
# Out:
# 1864

# %%
df_movements_joined = df_movements_resampled.join(df_movements, rsuffix='_')

# %%
df_movements_joined = df_movements_joined.reset_index()

# %%
df_movements_joined.columns
# Out:
# Index(['datetime', 'rides', 'hour', 'month', 'year', 'day', 'rides_', 'date',
#        'weekday', 'hour_', 'month_', 'year_', 'day_', 'time'],
#       dtype='object')

# %%
df_movements_joined = df_movements_joined[['hour', 'month', 'year', 'day', 'rides', 'date', 'weekday','time', 'datetime']]
df_movements_joined
# Out:
#        hour  month  year  day  rides        date    weekday      time  \
# 0        23     12  2018   31    176  2018-12-31     Monday  23:00:00
# 1         0      1  2019    1    254  2019-01-01    Tuesday  00:00:00
# 2         1      1  2019    1    169  2019-01-01    Tuesday  01:00:00
# 3         2      1  2019    1    105  2019-01-01    Tuesday  02:00:00
# 4         3      1  2019    1     83  2019-01-01    Tuesday  03:00:00
# ...     ...    ...   ...  ...    ...         ...        ...       ...
# 21884    19      6  2021   30    813  2021-06-30  Wednesday  19:00:00
# 21885    20      6  2021   30    552  2021-06-30  Wednesday  20:00:00
# 21886    21      6  2021   30    571  2021-06-30  Wednesday  21:00:00
# 21887    22      6  2021   30    499  2021-06-30  Wednesday  22:00:00
# 21888    23      6  2021   30    264  2021-06-30  Wednesday  23:00:00
#
#                  datetime
# 0     2018-12-31 23:00:00
# 1     2019-01-01 00:00:00
# 2     2019-01-01 01:00:00
# 3     2019-01-01 02:00:00
# 4     2019-01-01 03:00:00
# ...                   ...
# 21884 2021-06-30 19:00:00
# 21885 2021-06-30 20:00:00
# 21886 2021-06-30 21:00:00
# 21887 2021-06-30 22:00:00
# 21888 2021-06-30 23:00:00
#
# [21889 rows x 9 columns]

# %% [markdown]
# Now we are going to add the information about the holidays calendar to the dataframe. We are going to perform the join with the date column of both tables

# %%
df_movements_joined['date'] = df_movements_joined.date.astype('datetime64[ns]')
holidays_df['date']=holidays_df.date.astype('datetime64[ns]')
# Out:
# <ipython-input-41-430ea4b05b62>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   holidays_df['date']=holidays_df.date.astype('datetime64[ns]')

# %%
df_movements_joined = df_movements_joined.merge(holidays_df, how='left', on='date')

# %%
df_movements_joined = df_movements_joined[['date', 'weekday', 'day_x', 'hour', 'time', 'month', 'rides', 'holiday', 'datetime']]

# %%
df_movements_joined
# Out:
#             date    weekday  day_x  hour      time  month  rides  holiday  \
# 0     2018-12-31     Monday     31    23  23:00:00     12    176      NaN
# 1     2019-01-01    Tuesday      1     0  00:00:00      1    254  festivo
# 2     2019-01-01    Tuesday      1     1  01:00:00      1    169  festivo
# 3     2019-01-01    Tuesday      1     2  02:00:00      1    105  festivo
# 4     2019-01-01    Tuesday      1     3  03:00:00      1     83  festivo
# ...          ...        ...    ...   ...       ...    ...    ...      ...
# 21884 2021-06-30  Wednesday     30    19  19:00:00      6    813      NaN
# 21885 2021-06-30  Wednesday     30    20  20:00:00      6    552      NaN
# 21886 2021-06-30  Wednesday     30    21  21:00:00      6    571      NaN
# 21887 2021-06-30  Wednesday     30    22  22:00:00      6    499      NaN
# 21888 2021-06-30  Wednesday     30    23  23:00:00      6    264      NaN
#
#                  datetime
# 0     2018-12-31 23:00:00
# 1     2019-01-01 00:00:00
# 2     2019-01-01 01:00:00
# 3     2019-01-01 02:00:00
# 4     2019-01-01 03:00:00
# ...                   ...
# 21884 2021-06-30 19:00:00
# 21885 2021-06-30 20:00:00
# 21886 2021-06-30 21:00:00
# 21887 2021-06-30 22:00:00
# 21888 2021-06-30 23:00:00
#
# [21889 rows x 9 columns]

# %% [markdown]
# The column holiday has information only when the day is a holiday, we are going to transform the column so it has a 1 when the day is a holiday and 0 the rest of the days

# %%
df_movements_joined['date'] = df_movements_joined['datetime'].dt.date
df_movements_joined['day_x'] = df_movements_joined['datetime'].dt.day
df_movements_joined['hour'] = df_movements_joined['datetime'].dt.hour
df_movements_joined['month'] = df_movements_joined['datetime'].dt.month
df_movements_joined['weekday'] = df_movements_joined['datetime'].dt.day_name()
df_movements_joined['time'] = df_movements_joined['datetime'].dt.time
df_movements_joined['year'] = df_movements_joined['datetime'].dt.year

# %%
missingno.matrix(df_movements_joined)
# Out:
# <AxesSubplot:>

# %%
df_movements_joined.fillna("no festivo", inplace = True)
dic_holidays = {'no festivo': 0, 'festivo': 1}
holidays_df = pd.DataFrame([[key, dic_holidays[key]] for key in dic_holidays.keys()], columns = ['holiday', 'is_holiday'])
df_movements_joined=df_movements_joined.merge(holidays_df,how='inner', left_on='holiday', right_on='holiday')

# %%
df_movements_joined
# Out:
#              date    weekday  day_x  hour      time  month  rides     holiday  \
# 0      2018-12-31     Monday     31    23  23:00:00     12    176  no festivo
# 1      2019-01-02  Wednesday      2     0  00:00:00      1     52  no festivo
# 2      2019-01-02  Wednesday      2     1  01:00:00      1     29  no festivo
# 3      2019-01-02  Wednesday      2     2  02:00:00      1     32  no festivo
# 4      2019-01-02  Wednesday      2     3  03:00:00      1     23  no festivo
# ...           ...        ...    ...   ...       ...    ...    ...         ...
# 21500  2021-01-06  Wednesday      6    19  19:00:00      1    277     festivo
# 21501  2021-01-06  Wednesday      6    20  20:00:00      1    219     festivo
# 21502  2021-01-06  Wednesday      6    21  21:00:00      1    191     festivo
# 21503  2021-01-06  Wednesday      6    22  22:00:00      1    212     festivo
# 21504  2021-01-06  Wednesday      6    23  23:00:00      1    120     festivo
#
#                  datetime  year  is_holiday
# 0     2018-12-31 23:00:00  2018           0
# 1     2019-01-02 00:00:00  2019           0
# 2     2019-01-02 01:00:00  2019           0
# 3     2019-01-02 02:00:00  2019           0
# 4     2019-01-02 03:00:00  2019           0
# ...                   ...   ...         ...
# 21500 2021-01-06 19:00:00  2021           1
# 21501 2021-01-06 20:00:00  2021           1
# 21502 2021-01-06 21:00:00  2021           1
# 21503 2021-01-06 22:00:00  2021           1
# 21504 2021-01-06 23:00:00  2021           1
#
# [21505 rows x 11 columns]

# %% [markdown]
# We are also going to add a column: ``is_weekend``, this column will have the value 1 when the day is weekend.

# %%
def is_weekend(weekday):
    '''Giving a day as an input string returns True if day is in the weekend'''
    if weekday == 'Saturday' or weekday == "Sunday" or weekday == "saturday" or weekday == "sunday":
        return 1
    else:
        return 0

# %%
df_movements_joined['is_weekend'] = df_movements_joined['weekday'].apply(is_weekend)

# %%
#We convert the dataframe in a csv file that we will use for our models
df_movements_joined.to_csv('movements_grouped.csv')

# %% [markdown]
# ### 4.2. Dataframe with rides per station

# %%
movements.columns
# Out:
# Index(['user_type', 'travel_time', 'idunplug_station', 'ageRange',
#        'idplug_station', 'zip_code', 'datetime', 'date', 'weekday', 'hour',
#        'month', 'year', 'day', 'time'],
#       dtype='object')

# %%
df_movements_station =  movements.groupby(['idunplug_station','date', 'weekday', 'hour', 'month', 
                                           'year', 'day', 'time','datetime']).ageRange.count().reset_index()

# %%
df_movements_station['rides'] = df_movements_station['ageRange']
df_movements_station = df_movements_station[['idunplug_station', 'date', 'weekday', 'hour', 'month', 'year', 'day',
       'time', 'datetime',  'rides']]

# %% [markdown]
# We are going to join the dataframe we created previously ``stations`` with the number of rides per station in the dataframe ``df_movements_station`` in order to have information about the stations of the pickup in one table

# %%
stations
# Out:
#                        name           longitude           latitude  \
# 0          Puerta del Sol A          -3.7018341         40.4172137
# 1          Puerta del Sol B  -3.701602938060457  40.41731271011562
# 2               Miguel Moya          -3.7058415         40.4205886
# 3        Plaza Conde Suchil          -3.7069171         40.4302937
# 4                  Malasaña          -3.7025875         40.4285524
# ..                      ...                 ...                ...
# 259                    INEF            -3.72997           40.43896
# 260  Ciudad Universitaria 1            -3.72699           40.44375
# 261  Ciudad Universitaria 2            -3.72693           40.44342
# 262       Facultad Biología          -3.7272945         40.4483322
# 263        Facultad Derecho            -3.72937           40.45109
#
#                                                address  total_bases   id  \
# 0                                  Puerta del Sol nº 1           30    1
# 1                                  Puerta del Sol nº 1           30    2
# 2                               Calle Miguel Moya nº 1           24    3
# 3             Plaza del Conde del Valle de Súchil nº 3           18    4
# 4                          Calle Manuela Malasaña nº 5           24    5
# ..                                                 ...          ...  ...
# 259  Avenida Juan de Herrera frente a la calle Paul...           24  265
# 260  Avenida de la Complutense (Metro Ciudad Univer...           24  266
# 261  Avenida de la Complutense (Metro Ciudad Univer...           24  267
# 262          Calle José Antonio Novais frente al nº 12           24  268
# 263                          Avenida Complutense nº 23           24  269
#
#     number
# 0       1a
# 1       1b
# 2        2
# 3        3
# 4        4
# ..     ...
# 259    257
# 260    258
# 261    259
# 262    260
# 263    261
#
# [264 rows x 7 columns]

# %% [markdown]
# There are 264 stations of bicimad in Madrid, we are going to analyze the demand by zone, so we need to know the postal code of each stations, and we will group stations by postal code

# %%
#We create a column that has the information about latitude and longitude
stations['location'] = stations['latitude'].map(str) + "," + stations['longitude'].map(str)

# %%
stations
# Out:
#                        name           longitude           latitude  \
# 0          Puerta del Sol A          -3.7018341         40.4172137
# 1          Puerta del Sol B  -3.701602938060457  40.41731271011562
# 2               Miguel Moya          -3.7058415         40.4205886
# 3        Plaza Conde Suchil          -3.7069171         40.4302937
# 4                  Malasaña          -3.7025875         40.4285524
# ..                      ...                 ...                ...
# 259                    INEF            -3.72997           40.43896
# 260  Ciudad Universitaria 1            -3.72699           40.44375
# 261  Ciudad Universitaria 2            -3.72693           40.44342
# 262       Facultad Biología          -3.7272945         40.4483322
# 263        Facultad Derecho            -3.72937           40.45109
#
#                                                address  total_bases   id  \
# 0                                  Puerta del Sol nº 1           30    1
# 1                                  Puerta del Sol nº 1           30    2
# 2                               Calle Miguel Moya nº 1           24    3
# 3             Plaza del Conde del Valle de Súchil nº 3           18    4
# 4                          Calle Manuela Malasaña nº 5           24    5
# ..                                                 ...          ...  ...
# 259  Avenida Juan de Herrera frente a la calle Paul...           24  265
# 260  Avenida de la Complutense (Metro Ciudad Univer...           24  266
# 261  Avenida de la Complutense (Metro Ciudad Univer...           24  267
# 262          Calle José Antonio Novais frente al nº 12           24  268
# 263                          Avenida Complutense nº 23           24  269
#
#     number                              location
# 0       1a                 40.4172137,-3.7018341
# 1       1b  40.41731271011562,-3.701602938060457
# 2        2                 40.4205886,-3.7058415
# 3        3                 40.4302937,-3.7069171
# 4        4                 40.4285524,-3.7025875
# ..     ...                                   ...
# 259    257                     40.43896,-3.72997
# 260    258                     40.44375,-3.72699
# 261    259                     40.44342,-3.72693
# 262    260                 40.4483322,-3.7272945
# 263    261                     40.45109,-3.72937
#
# [264 rows x 8 columns]

# %% [markdown]
# We want to obtain the postal code given the location in coordinates. We are going to use the library geopy for this

# %%
#! pip install geopy
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
#We save in stations_locations information about the latitude and longitude of each station
stations_locations = stations['location']

# %%
#we use the geolocator.geocode to obtain the address of each station
address=[]

for location in stations_locations:
    address += geolocator.geocode(location)

# %%
address
# Out:
# ['3, Calle de Alcalá, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.4172987, -3.7018201),
#  'Ministerio de Hacienda y Función Pública, 9, Calle de Alcalá, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.41781225, -3.701547519484942),
#  'Palacio de la Prensa, Calle de los Tudescos, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4206956, -3.7059349201176444),
#  'BBK, Plaza del Conde del Valle Suchil, Arapiles, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4301761, -3.7071302),
#  'Le Gallinero, Calle de Manuela Malasaña, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4285311, -3.7025807),
#  '108, Calle de Fuencarral, Malasaña, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4285102, -3.7020707),
#  'Colegio Oficial de Arquitectos de Madrid, Calle de Santa Brígida, Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.42416115, -3.698553009773362),
#  '75, Calle de Hortaleza, Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4252365, -3.6977801),
#  'Calle de Almagro, Almagro, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4279098, -3.6953497),
#  'BBVA, Plaza de San Miguel, Barrio de la Latina, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4156013, -3.709523),
#  'Colón (metro), Calle del Marqués de la Ensenada, Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4253318, -3.6921501),
#  '18, Calle de San Andrés, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4269733, -3.7035887),
#  '85, Calle de San Bernardo, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28015, España',
#  (40.4284441, -3.7063184),
#  '22, Calle del Conde Duque, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28015, España',
#  (40.4273395, -3.7104501),
#  'Colegio Madres Concepcionistas, Calle de Ventura Rodríguez, Argüelles, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4263367, -3.7134799005454884),
#  'Imprenta 13, 13, Calle del Norte, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28015, España',
#  (40.4262978, -3.7074302),
#  'Kinza, 22, Calle de San Bernardo, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28015, España',
#  (40.4230675, -3.7074134),
#  'Lamucca, 4, Plaza de Carlos Cambronero, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4232926, -3.703864),
#  'Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.420970600000004, -3.699151837323062),
#  'Panod, 1, Calle de Prim, Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4219685, -3.6954978),
#  'Instituto Cervantes, Calle del Barquillo, Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4195621, -3.695366346114337),
#  'Colegio de Gestores Administrativos de Madrid, Calle de Jacometrezo, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.420043750000005, -3.7067122735599227),
#  "Domingo's, Calle de Jacometrezo, Barrio de los Austrias, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28013, España",
#  (40.4203546, -3.7079386),
#  'Bicimad 24, Calle de Carlos III, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.417916, -3.7106737),
#  '1, Calle de Tetuán, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28013, España',
#  (40.41753985, -3.7056692470224277),
#  'Petit Palace Arenal, 16, Calle Arenal, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28013, España',
#  (40.4172778, -3.7064049),
#  'BiciMAD, Plaza de las Salesas, Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.423816, -3.6945162),
#  'Stop Madrid, 4, Calle de Jesús, Barrio de las Letras, Cortes, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.4133019, -3.6957),
#  'Consejería de Educación e Investigación, 30;32, Calle de Alcalá, Barrio de las Letras, Cortes, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.4179965, -3.6978359572662614),
#  '25, Calle del Marqués de Cubas, Barrio de las Letras, Cortes, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.4162499, -3.6957617),
#  'Bicimad 30, Plaza de Oriente, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.419319, -3.711513),
#  'La Caixa, Calle Mayor, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28013, España',
#  (40.4163626, -3.7068957),
#  'Adhesión de España a las Comunidades Europeas, Plaza de la Provincia, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4149176, -3.7060271),
#  'Hostal Victoria II, 3, Calle de Carretas, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4164716, -3.7030606),
#  '100 Montaditos, Plaza de Jacinto Benavente, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4148124, -3.7037475),
#  'Antonio Pérez, Calle del Sacramento, Barrio de la Latina, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4142662, -3.7101269),
#  'BiciMAD, Plaza de Ramales, Barrio de la Latina, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28013, España',
#  (40.416802, -3.7118522),
#  'San Francisco de Asís, Calle San Buenaventura, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.410876, -3.7144952),
#  'Palacio del Duque del Infantado, Plaza de los Carros, Barrio de la Latina, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.411338099999995, -3.711865577194426),
#  'Teatro La Latina, 2, Plaza de la Cebada, Barrio de la Latina, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4115711, -3.708772971526286),
#  '11, Calle de la Concepción Jerónima, Barrio de los Austrias, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4138976, -3.7050847),
#  'Museo del Jamón, Calle de Atocha, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4122258, -3.6991251),
#  '32, Calle de Santa Isabel, Lavapiés, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4107173, -3.6982242),
#  '29, Calle de Lavapiés, Lavapiés, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4101202, -3.7023666),
#  '44, Calle del Mesón de Paredes, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4097129, -3.7040747),
#  'Puerta de Toledo, Calle de Toledo, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4070507, -3.7110664),
#  '28, Ribera de Curtidores, Las Acacias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4053523, -3.7071487),
#  'Gta. Embajadores, Glorieta de Embajadores, Las Acacias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4046738, -3.702815),
#  'Casa de Baños, Calle de Miguel Servet, Lavapiés, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4055369, -3.7019918129441622),
#  '36, Ronda de Atocha, Lavapiés, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4060853, -3.6992591),
#  'Museo Nacional Centro de Arte Reina Sofía, 52, Calle de Santa Isabel, Lavapiés, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.408049500000004, -3.694421591348541),
#  'Pza. Emperador Carlos V - R. Atocha, Túnel de Atocha, Atocha, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4075073, -3.6935134),
#  '9, Plaza de Santa Ana, Barrio de las Letras, Cortes, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.41427195, -3.7006971410551754),
#  'Bicimad 53, Plazuela de Ana Diosdado, Lavapiés, Embajadores, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28012, España',
#  (40.4083293, -3.700695),
#  'BiciMAD, Calle de Barceló, Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.426635, -3.7004302),
#  'Parroquia San Ildefonso, 16, Calle de Colón, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4239972, -3.7018032037822803),
#  'Teatro Muñoz Seca, 1, Plaza del Carmen, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28013, España',
#  (40.4183658, -3.7032747),
#  'Sta. Cruz Marcenado - Mártires Alcalá, Calle de Santa Cruz de Marcenado, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4294992, -3.712683),
#  '33, Calle de Augusto Figueroa, Chueca, Justicia, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4222731, -3.6979039),
#  '32, Calle del Espíritu Santo, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4255212, -3.7043411),
#  'La puerta de Alcalá, Plaza de la Independencia, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4199823, -3.6887104),
#  "Edificio O'Donnell, Carril bici calle O'Donnell, Recoletos, Ibiza, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España",
#  (40.421132549999996, -3.6746154464651397),
#  "46, Calle de O'Donnell, Ibiza, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España",
#  (40.4212678, -3.6731797),
#  '62, Calle de Ibiza, Ibiza, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.4178793, -3.6709381),
#  'Aparcamiento Residentes Antonio Maura, Calle Ruiz de Alarcón, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.4165692, -3.6903844927065563),
#  'Colegio Público Palacio Valdés, Calle Almadén, Barrio de las Letras, Cortes, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.410613749999996, -3.6929702970538703),
#  'Aparcamiento Residentes Espalter, Calle Espalter, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.412733349999996, -3.6905043482142696),
#  'Calle de Alfonso XII, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.409709, -3.688821),
#  'Jardines de Herrero Palacios, Avenida de Menéndez Pelayo, Niño Jesús, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.4156513, -3.678746923587338),
#  '28, Calle del Doce de Octubre, Niño Jesús, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.4159756, -3.6738728),
#  'Parroquia de San Estanislao de Kostka, 97, Calle del Doctor Esquerdo, Estrella, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.41595735, -3.6690495047734073),
#  'Bicimad, Plaza de los Astros, Estrella, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.4114561, -3.6689241),
#  'Avenida de Menéndez Pelayo, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.4131892, -3.6770011),
#  'Bicimad 75, Calle del Poeta Esteban de Villegas, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.408343, -3.6784396),
#  'Aparcamiento para residentes. Conde de Casal - Mediterráneo, Avenida del Mediterráneo, Niño Jesús, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.4070637, -3.673676914354216),
#  'Galápago, Plaza del Conde de Casal, Pacífico, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.40624, -3.6707329),
#  '190, Avenida de la Ciudad de Barcelona, Adelfas, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.40084925, -3.6746689996546142),
#  '38, Avenida de Menéndez Pelayo, Pacífico, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.40511645, -3.68068033421124),
#  'Bicimad 80B, Avenida de la Ciudad de Barcelona, Atocha, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.4074637, -3.6904315),
#  'Bicimad 80B, Avenida de la Ciudad de Barcelona, Atocha, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.4074637, -3.6904315),
#  'Paseo del Prado, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28014, España',
#  (40.4091023, -3.691859),
#  'BiciMAD, Calle de Lira, Estrella, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.4084897, -3.6697922),
#  'Centro de Mayores "Pío Baroja", Calle de Pío Baroja, Niño Jesús, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.41335555, -3.674626133148896),
#  '191, Calle del Doctor Esquerdo, Adelfas, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.403220399999995, -3.672568950444748),
#  'BiciMAD, Avenida de Menéndez Pelayo, Ibiza, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.420828, -3.679806),
#  'Cibeles, Paseo del Prado, Jerónimos, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4185422, -3.6932745),
#  'Residencia Santa María del Monte Carmelo, Calle de Ayala, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.427956550000005, -3.683361461285111),
#  '75, Calle de Velázquez, Castellana, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28006, España',
#  (40.431356, -3.6837958),
#  '75, Calle de Ayala, Goya, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4273642, -3.6751837),
#  'Menbur, Calle de Goya, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4250138, -3.6837735),
#  'Tacoos, 73, Calle de Hermosilla, Goya, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4261557, -3.6787937),
#  '51, Calle de Claudio Coello, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.426905899999994, -3.686725756190456),
#  'BiciMAD, Plaza de Margaret Thatcher, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4257385, -3.6894039),
#  '94, Paseo de Recoletos, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4232449, -3.6908398),
#  '19, Calle de Claudio Coello, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4227067, -3.6870298),
#  '111, Calle de Alcalá, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4220865, -3.6821757),
#  '2, Avenida de Menéndez Pelayo, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.42232285, -3.680471342505826),
#  'Narváez - Av. Felipe II, Avenida Felipe II, Goya, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.4238595, -3.6760155),
#  'BiciMAD, Calle Alcántara, Goya, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28006, España',
#  (40.4260264, -3.6739711),
#  'Volvo Servauto, 99, Calle de Goya, Goya, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.4247834, -3.6737594),
#  '34, Calle del Doctor Esquerdo, Goya, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.4232637, -3.669130364357589),
#  '95, Calle de Alcalá, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.421244, -3.6840665),
#  'BiciMAD, Calle de José Ortega y Gasset, Castellana, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28006, España',
#  (40.4303607, -3.686648),
#  'Sinsombrero, 4, Paseo de la Castellana, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28046, España',
#  (40.4269232, -3.6894651),
#  '105, Acera Bici Serrano, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4271234, -3.6874687),
#  '106A, Acera Bici Serrano, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4249614, -3.6878557),
#  '32, Calle de Serrano, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4248982, -3.6877564),
#  'Diesel, Acera Bici Serrano, Recoletos, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4222588, -3.6881731),
#  '108. Mártires Concepcionistas, Calle de los Mártires Concepcionistas, Goya, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4273751, -3.6706463),
#  '30, Calle de José Ortega y Gasset, Castellana, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4300393, -3.6817364),
#  'Bicimad, Paseo de Moret, Casa de Campo, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4348233, -3.7199909),
#  'Hotel Exe Moncloa, 10, Calle del Arcipreste de Hita, Gaztambide, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28015, España',
#  (40.433855949999995, -3.71746141448643),
#  'Moncloa, Calle del Arcipreste de Hita, Argüelles, Moncloa-Aravaca, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4340736, -3.7180316),
#  '112, Paseo de Moret, Casa de Campo, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4326145, -3.7249201),
#  'BiciMAD, Paseo del Pintor Rosales, Argüelles, Casa de Campo, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4277735, -3.7206994),
#  'Centro de Especialidades Argüelles, Calle de Quintana, Argüelles, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4277276, -3.7170798035724157),
#  '115, Calle de Evaristo San Miguel, Argüelles, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4254154, -3.7169147),
#  'Pza. de España, Plaza de España, Argüelles, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28008, España',
#  (40.4239722, -3.7117026),
#  'Bicimad 116a, Plaza de España, Argüelles, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28008, España',
#  (40.4240745, -3.7117539),
#  'BiciMAD, Calle de Altamirano, Argüelles, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4309201, -3.7189154),
#  'Bicimad 118, Calle de Juan Martín El Empecinado, Palos de Moguer, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.40072, -3.688154),
#  'Bicimad 119, Calle de Méndez Álvaro, Atocha, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.4010658, -3.6861543),
#  '29, Calle de Palos de la Frontera, Palos de Moguer, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.40327255, -3.694462006724028),
#  '60, Paseo de Santa María de la Cabeza, Palos de Moguer, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.40180335, -3.6990791678885024),
#  'Apostólicas del Corazón de Jesús, Calle de José Marañón, Trafalgar, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4293825, -3.6968824483126004),
#  'Metropolytan, 2, Calle de Guzmán el Bueno, Gaztambide, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4306356, -3.7133582),
#  '20, Calle de Manuel Silvela, Trafalgar, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.430884899999995, -3.69917826527237),
#  'BiciMAD, Calle de Fernández de la Hoz, Almagro, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28010, España',
#  (40.4352707, -3.694834),
#  'Banca March, Calle de Eloy Gonzalo, Trafalgar, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.43443, -3.7015413),
#  'BiciMAD, Calle de Fernando el Católico, Arapiles, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4339145, -3.7085176),
#  '128, Calle de Cea Bermúdez, Gaztambide, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4390127, -3.7154142),
#  'La Tahona de Ponzano, Calle de José Abascal, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4384957, -3.6982419),
#  'BiciMAD, Carril bici Santa Engracia, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4413286, -3.701639),
#  'BiciMAD, Calle de Bravo Murillo, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.4418453, -3.7040271),
#  'BiciMAD, Calle de Santa Engracia, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.4463877, -3.7035899),
#  '33, Calle de Raimundo Fernández Villaverde, Cuatro Caminos, Tetuán, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.44690435, -3.700256812055976),
#  'BiciMAD, Calle de María de Guzmán, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4440385, -3.6956411),
#  'BiciMAD, Plaza de San Juan de la Cruz, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.4415019, -3.6927776),
#  'BiciMAD, Paseo de la Castellana, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4454067, -3.6907876),
#  'República Argentina, Plaza de la República Argentina, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4453372, -3.6852423),
#  'Centro de Educación Infantil del Ministerio de Fomento, Calle de Raimundo Fernández Villaverde, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.445890649999996, -3.692439657305629),
#  'Estatua ecuestre Isabel I La Católica, Paseo de la Castellana, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4403223, -3.6907586),
#  '131, Calle de Velázquez, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28006, España',
#  (40.438559350000006, -3.683370324064052),
#  'Paseo de la Castellana, Almagro, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4358824, -3.6893212),
#  '42, Paseo de la Castellana, Castellana, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28046, España',
#  (40.4333484, -3.687609005334834),
#  'Confederación Española de Organizaciones Empresariales, 50, Calle de Diego de León, Lista, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28006, España',
#  (40.434433, -3.6789153069394542),
#  'BiciMAD, Calle de Juan Bravo, Lista, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4323147, -3.6754885),
#  'C.Est.Profes.Advos.y Lingüísticos (Cepal), Calle de José Ortega y Gasset, Lista, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4298593, -3.6712953),
#  'BiciMAD, Calle María Francisca, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4442195, -3.6786581),
#  '45, Avenida del Doctor Arce, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28006, España',
#  (40.44841005, -3.6797404),
#  'BiciMAD, Calle Serrano, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4511234, -3.681645),
#  'Buzón de Correos, Calle Santiago Bernabéu, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4498597, -3.6882016),
#  'BiciMAD, Paseo de la Castellana, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.448962, -3.690665),
#  'Crowhill Shoes, Calle de Orense, Cuatro Caminos, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4488174, -3.695073),
#  '152, Avenida del General Perón, Cuatro Caminos, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4527113, -3.6990229),
#  'Avenida del General Perón, AZCA, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4522231, -3.6935795),
#  '36, Calle de Orense, Cuatro Caminos, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28020, España',
#  (40.4548444, -3.6946396),
#  '55, Calle de San Germán, Cuatro Caminos, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28020, España',
#  (40.4572724, -3.7009211),
#  'BiciMAD, Calle de Sor Ángela de la Cruz, Castillejos, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4593134, -3.6916347),
#  'BiciMAD, Plaza de Cuzco, Costa Fleming, Nueva España, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4592665, -3.6893096),
#  '22A, Avenida de Alberto Alcocer, Hispanoamérica, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.45846405, -3.684719171150909),
#  '63, Paseo de La Habana, Hispanoamérica, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4543536, -3.683764724402908),
#  '9, Calle de Colombia, Hispanoamérica, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28016, España',
#  (40.457235, -3.6763717),
#  '25, Paseo de la Florida, Casa de Campo, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28008, España',
#  (40.421964450000004, -3.722451284296472),
#  'The Towers, Travesía de San Isidoro de Sevilla, Las Acacias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4033082, -3.7108266),
#  'BiciMAD, Paseo de la Esperanza, Las Acacias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4036955, -3.7064812),
#  '92, Paseo de las Delicias, Delicias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.3972611, -3.6945422),
#  'BiciMAD, Paseo de la Chopera, Chopera, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.3927904, -3.6976874),
#  'Viaducto de Segovia, Cuesta de Ramón, Palacio, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.413948399999995, -3.713640496359064),
#  'Bicimad Segovia 45, Calle de Segovia, Imperial, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4137352, -3.7175287),
#  'BiciMAD 168, Paseo de Santa María de la Cabeza, Palos de Moguer, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.4045057, -3.6959514),
#  'Aparcabicis Escuela Infantil Municial El Alba, Calle de Toledo, Las Acacias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.4016346, -3.7138264),
#  'BiciMAD, Paseo de la Esperanza, Las Acacias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.401102, -3.704416),
#  '97, Calle de Embajadores, Delicias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.39988485, -3.6982603488061376),
#  'BiciMAD, Calle de Bustamante, Palos de Moguer, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.4008745, -3.6936146),
#  'BiciMAD, Paseo de la Esperanza, Las Acacias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.3981428, -3.7023172),
#  'Baños públicos, Paseo de Yeserías, Las Acacias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.3973486, -3.7067105),
#  '30, Calle de Jaime I El Conquistador, Chopera, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.3962053, -3.6985136122722304),
#  'Garaje Plaza Legazpi, Calle de Alicante, Delicias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.394604150000006, -3.6937183601143673),
#  '3, Calle Bolívar, Legazpi, Delicias, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.39158904999999, -3.6942244499999974),
#  '3, Calle de León Gil de Palacio, Pacífico, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.402782, -3.6786539001381624),
#  'BiciMAD, Calle Monte Ulía, San Diego, Puente de Vallecas, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.3979014, -3.6691413),
#  '5, Calle de la Retama, Atocha, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.393967700000005, -3.6757053348676623),
#  '16, Calle de Ibiza, Ibiza, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.4181513, -3.6766994),
#  'Sainz de Baranda - Juan Esplandiú, Calle del Alcalde Sáinz de Baranda, Estrella, Retiro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28007, España',
#  (40.4186561, -3.665875),
#  '135, Calle de Hermosilla, Goya, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28009, España',
#  (40.4256683, -3.6693714),
#  '24, Paseo del Marqués de Zafra, Fuente del Berro, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.4258909, -3.665375071792088),
#  'Calle de Sancho Dávila, Fuente del Berro, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.425085, -3.6616141),
#  '58, Calle del General Pardiñas, Lista, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.429115800000005, -3.6781045273752007),
#  '200, Calle de Alcalá, Fuente del Berro, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.4303091, -3.66374822719923),
#  '2, Avenida de Daroca, Ventas, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.43113685, -3.659107529989118),
#  'Calle de la Virgen de la Alegría, Concepción, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28027, España',
#  (40.434987, -3.6555953),
#  '91, Calle de Velázquez, Castellana, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28006, España',
#  (40.4342941, -3.683559),
#  'Centro de mayores Alonso Heredia, Calle de Alonso de Heredia, Guindalera, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.4346005, -3.6738285),
#  'MetLife, Avenida de los Toreros, Guindalera, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4320261, -3.671393750000001),
#  'Avenida de los Toreros, Madrid Moderno, Guindalera, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.4324835, -3.6655018),
#  'BiciMAD, Calle de Francisco Silvela, Guindalera, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4372428, -3.6772168),
#  'BiciMAD, Calle de Mataelpino, Prosperidad, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4392144, -3.6754819),
#  '2, Calle de Suero de Quiñones, Ciudad Jardín, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28002, España',
#  (40.4441983, -3.6751408),
#  '69, Avenida de Concha Espina, Hispanoamérica, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4518846, -3.6780048),
#  '2, Plaza de Rubén Darío, Almagro, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28010, España',
#  (40.4332173, -3.6916098),
#  '68, Calle de Fernando el Católico, Gaztambide, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28015, España',
#  (40.4344325, -3.7149362),
#  '200, Calle de Arapiles, Arapiles, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4336546, -3.704677),
#  '201, Calle de José Abascal, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4387427, -3.7038126),
#  'Rizal, Calle de Santander, Vallehermoso, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.441171, -3.70786675),
#  'Parquímetro, Calle del General Ampudia, Vallehermoso, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.4421613, -3.7148517),
#  '1, Calle del Doctor Santero, Bellas Vistas, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28039, España',
#  (40.4476317, -3.7042705),
#  'BiciMAD, Calle Navarra, Bellas Vistas, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4535094, -3.703265),
#  'L11 Marqués de Viana - Bravo Murillo, Túnel Marqués de Viana - Sor Ángela de la Cruz, Berruguete, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4606602, -3.6987573),
#  'BiciMAD, Calle de las Azucenas, Valdeacederas, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4630503, -3.6972729),
#  '208, Paseo de la Castellana, Castilla, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4663872, -3.6887115),
#  '209, Plaza de Castilla, Costa Fleming, Nueva España, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4656937, -3.6887649),
#  'Brindis Pub, Calle de las Tres Cruces, Barrio de los Austrias, Sol, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28013, España',
#  (40.4195594, -3.7026484),
#  '4, Calle del Desengaño, Malasaña, Universidad, Centro, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28004, España',
#  (40.4206967, -3.7025243),
#  'Caixabank, Avenida Emperatriz Isabel, San Isidro, Carabanchel, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.3979483, -3.7167031),
#  '117, Calle de Antonio López, Moscardó, Usera, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28026, España',
#  (40.389361449999996, -3.700413841842215),
#  'Edificio Los Cubos, Calle de Albacete, San Pascual, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.44319445, -3.657842995677553),
#  'Centro Municipal de Mayores "Ascao", Calle de Gutierre de Cetina, Pueblo Nuevo, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.42953705, -3.6412787813598397),
#  'Paseo de Extremadura, Puerta del Ángel, Latina, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4136797, -3.7281483),
#  'Ciudad Sanitaria La Paz, Calle del Arzobispo Morcillo, La Paz, Fuencarral-El Pardo, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28029, España',
#  (40.48144225, -3.6872531870474865),
#  'Cº Vinateros - Corr. D. Valderrabano, Calle del Camino de los Vinateros, Media Legua, Moratalaz, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28030, España',
#  (40.4105363, -3.6578753),
#  '108, Calle del Camino de los Vinateros, Marroquina, Moratalaz, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28030, España',
#  (40.408135099999996, -3.646864949999997),
#  '6, Calle del Arroyo de las Pilillas, Marroquina, Moratalaz, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28030, España',
#  (40.40691785, -3.6514923862697306),
#  'Lidl, 346, Calle de la Hacienda de Pavones, Pavones, Moratalaz, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28030, España',
#  (40.40003245, -3.6346398832947067),
#  'Aparcabicis Madrid Río, Calle de Eugenio Caxes, Moscardó, Usera, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28026, España',
#  (40.3917822, -3.7026844),
#  'La Plaza, Paseo de la Ermita del Santo, Cármenes, Latina, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28011, España',
#  (40.4066719, -3.7246693),
#  '51, Calle de Caramuel, Puerta del Ángel, Latina, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.409063149999994, -3.7284802067737495),
#  'Lidl, 33, Calle de la Sierra Toledana, Numancia, Puente de Vallecas, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28038, España',
#  (40.40255325, -3.6605350509890604),
#  '86, Camino de Valderribas, Numancia, Puente de Vallecas, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28038, España',
#  (40.399009899999996, -3.661154258726058),
#  'BiciMAD, Calle del Arroyo del Olivar, San Diego, Puente de Vallecas, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28053, España',
#  (40.3940296, -3.6661256),
#  'BiciMad, Calle de San Delfín, Comillas, Carabanchel, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28019, España',
#  (40.394408, -3.7080125),
#  'Calle José del Hierro, Concepción, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28027, España',
#  (40.4371774, -3.64832),
#  'Calle de Carlota O’Neill, San Pascual, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4437985, -3.6490607),
#  '12, Calle de los Derechos Humanos, San Pascual, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28027, España',
#  (40.4396562, -3.655554107991894),
#  '1, Calle de José María de Pereda, Ventas, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28017, España',
#  (40.4327273, -3.6484858),
#  '12, Avenida del Marqués de Corbera, Ventas, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28017, España',
#  (40.4228553, -3.6554595),
#  'Aparcabicis Metro La Elipa, Avenida del Marqués de Corbera, Ventas, Ciudad Lineal, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.42625, -3.6509444),
#  'Calle del Sodio, Legazpi, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28045, España',
#  (40.3893486, -3.6900189),
#  'Centro Deportivo Municipal Marqués de Samaranch, 20, Paseo Imperial, Imperial, Arganzuela, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28005, España',
#  (40.407432850000006, -3.717567798033207),
#  '237, Calle Francisco Balseiro, Bellas Vistas, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4513767, -3.7105021),
#  'San Germán - Poeta Joan Maragall, Calle de San Germán, Cuatro Caminos, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4562279, -3.6928286),
#  '62, Calle de Francos Rodríguez, Berruguete, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28039, España',
#  (40.4567751, -3.7079723),
#  'Avenida de Brasilia, Guindalera, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.4365412, -3.6610238),
#  'Avenida de Camilo José Cela, Guindalera, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.4369441, -3.6674745),
#  '52, Avenida de Bruselas, Guindalera, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.438611449999996, -3.6628254370490367),
#  'Cartagena - Eraso, Calle de Cartagena, Guindalera, Salamanca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28028, España',
#  (40.4342646, -3.670318),
#  '44, Calle de Isaac Peral, Vallehermoso, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.4400341, -3.7174979),
#  '63, Calle de Galileo, Arapiles, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28015, España',
#  (40.4364391, -3.7102359),
#  'Vips, Carril bici Santa Engracia, Trafalgar, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4364238, -3.6995944),
#  'Las Bridas, Calle de Zurbano, Ríos Rosas, Chamberí, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28003, España',
#  (40.4382715, -3.6927246),
#  '248, Calle de Sinesio Delgado, Almenara, La Paz, Tetuán, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28029, España',
#  (40.4743382, -3.6879171),
#  '249, Paseo de la Castellana, Castilla, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4794218, -3.6853806),
#  'CSIC Centro de Física Miguel A. Catalán, 113, Calle de Serrano, El Viso, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.441110800000004, -3.686338186213655),
#  'Aparcabicis Ejes principales del Plan Director, Calle de Santa Hortensia, Prosperidad, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4441888, -3.666953),
#  'BiciMAD, Calle de Rodríguez Jaén, Castilla, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.471561, -3.683916),
#  '7, Calle Doctor Fleming, Hispanoamérica, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4557046, -3.6885382),
#  'La Plaza de DIA, Avenida de Alfonso XIII, Costa Fleming, Nueva España, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4605261, -3.6770792),
#  'Ginos López Pozas, 2, Calle del General López Pozas, Costa Fleming, Nueva España, Chamartín, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4637916, -3.685037),
#  'Beatriz de Bobadilla - Juan Montalvo, Calle Beatriz de Bobadilla, Ciudad Universitaria, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4465563, -3.7137861),
#  'E.T.S. Arquitectura de Madrid, Avenida Juan de Herrera, Ciudad Universitaria, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4402099, -3.7310053199541633),
#  'Ciudad Universitaria, Avenida de Séneca, Ciudad Universitaria, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4463084, -3.726485605817154),
#  'Ciudad Universitaria, Avenida de Séneca, Ciudad Universitaria, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4463084, -3.726485605817154),
#  'Ciudad Universitaria, Avenida de Séneca, Ciudad Universitaria, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4463084, -3.726485605817154),
#  'Ciudad Universitaria, Avenida de Séneca, Ciudad Universitaria, Moncloa-Aravaca, Madrid, Área metropolitana de Madrid y Corredor del Henares, Comunidad de Madrid, 28001, España',
#  (40.4463084, -3.726485605817154)]

# %%
def is_even(number):
    if number % 2 == 0:
        return False
    return True

# %%
postal_code = []
df_address = pd.DataFrame(address, columns = ['address'] )
df_address['index'] = df_address.index
df_address['remove'] = df_address['index'].apply(is_even)
df_address = df_address[df_address['remove']==False]
df_address['list_addresses'] = df_address['address'].str.split(", ")
list_addresses = df_address['list_addresses'].to_list()
postal_code=[]
for i,lista in enumerate(list_addresses):
    postal_code.append(lista[-2])

# %%
list_addresses
# Out:
# [['3',
#   'Calle de Alcalá',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Ministerio de Hacienda y Función Pública',
#   '9',
#   'Calle de Alcalá',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Palacio de la Prensa',
#   'Calle de los Tudescos',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['BBK',
#   'Plaza del Conde del Valle Suchil',
#   'Arapiles',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Le Gallinero',
#   'Calle de Manuela Malasaña',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['108',
#   'Calle de Fuencarral',
#   'Malasaña',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Colegio Oficial de Arquitectos de Madrid',
#   'Calle de Santa Brígida',
#   'Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['75',
#   'Calle de Hortaleza',
#   'Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Calle de Almagro',
#   'Almagro',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BBVA',
#   'Plaza de San Miguel',
#   'Barrio de la Latina',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['Colón (metro)',
#   'Calle del Marqués de la Ensenada',
#   'Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['18',
#   'Calle de San Andrés',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['85',
#   'Calle de San Bernardo',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28015',
#   'España'],
#  ['22',
#   'Calle del Conde Duque',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28015',
#   'España'],
#  ['Colegio Madres Concepcionistas',
#   'Calle de Ventura Rodríguez',
#   'Argüelles',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Imprenta 13',
#   '13',
#   'Calle del Norte',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28015',
#   'España'],
#  ['Kinza',
#   '22',
#   'Calle de San Bernardo',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28015',
#   'España'],
#  ['Lamucca',
#   '4',
#   'Plaza de Carlos Cambronero',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Panod',
#   '1',
#   'Calle de Prim',
#   'Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Instituto Cervantes',
#   'Calle del Barquillo',
#   'Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Colegio de Gestores Administrativos de Madrid',
#   'Calle de Jacometrezo',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ["Domingo's",
#   'Calle de Jacometrezo',
#   'Barrio de los Austrias',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28013',
#   'España'],
#  ['Bicimad 24',
#   'Calle de Carlos III',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['1',
#   'Calle de Tetuán',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28013',
#   'España'],
#  ['Petit Palace Arenal',
#   '16',
#   'Calle Arenal',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28013',
#   'España'],
#  ['BiciMAD',
#   'Plaza de las Salesas',
#   'Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Stop Madrid',
#   '4',
#   'Calle de Jesús',
#   'Barrio de las Letras',
#   'Cortes',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Consejería de Educación e Investigación',
#   '30;32',
#   'Calle de Alcalá',
#   'Barrio de las Letras',
#   'Cortes',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['25',
#   'Calle del Marqués de Cubas',
#   'Barrio de las Letras',
#   'Cortes',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Bicimad 30',
#   'Plaza de Oriente',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['La Caixa',
#   'Calle Mayor',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28013',
#   'España'],
#  ['Adhesión de España a las Comunidades Europeas',
#   'Plaza de la Provincia',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Hostal Victoria II',
#   '3',
#   'Calle de Carretas',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['100 Montaditos',
#   'Plaza de Jacinto Benavente',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Antonio Pérez',
#   'Calle del Sacramento',
#   'Barrio de la Latina',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['BiciMAD',
#   'Plaza de Ramales',
#   'Barrio de la Latina',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28013',
#   'España'],
#  ['San Francisco de Asís',
#   'Calle San Buenaventura',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['Palacio del Duque del Infantado',
#   'Plaza de los Carros',
#   'Barrio de la Latina',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['Teatro La Latina',
#   '2',
#   'Plaza de la Cebada',
#   'Barrio de la Latina',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['11',
#   'Calle de la Concepción Jerónima',
#   'Barrio de los Austrias',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['Museo del Jamón',
#   'Calle de Atocha',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['32',
#   'Calle de Santa Isabel',
#   'Lavapiés',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['29',
#   'Calle de Lavapiés',
#   'Lavapiés',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['44',
#   'Calle del Mesón de Paredes',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['Puerta de Toledo',
#   'Calle de Toledo',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['28',
#   'Ribera de Curtidores',
#   'Las Acacias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['Gta. Embajadores',
#   'Glorieta de Embajadores',
#   'Las Acacias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['Casa de Baños',
#   'Calle de Miguel Servet',
#   'Lavapiés',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['36',
#   'Ronda de Atocha',
#   'Lavapiés',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['Museo Nacional Centro de Arte Reina Sofía',
#   '52',
#   'Calle de Santa Isabel',
#   'Lavapiés',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['Pza. Emperador Carlos V - R. Atocha',
#   'Túnel de Atocha',
#   'Atocha',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['9',
#   'Plaza de Santa Ana',
#   'Barrio de las Letras',
#   'Cortes',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['Bicimad 53',
#   'Plazuela de Ana Diosdado',
#   'Lavapiés',
#   'Embajadores',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28012',
#   'España'],
#  ['BiciMAD',
#   'Calle de Barceló',
#   'Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Parroquia San Ildefonso',
#   '16',
#   'Calle de Colón',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Teatro Muñoz Seca',
#   '1',
#   'Plaza del Carmen',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28013',
#   'España'],
#  ['Sta. Cruz Marcenado - Mártires Alcalá',
#   'Calle de Santa Cruz de Marcenado',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['33',
#   'Calle de Augusto Figueroa',
#   'Chueca',
#   'Justicia',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['32',
#   'Calle del Espíritu Santo',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['La puerta de Alcalá',
#   'Plaza de la Independencia',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ["Edificio O'Donnell",
#   "Carril bici calle O'Donnell",
#   'Recoletos',
#   'Ibiza',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['46',
#   "Calle de O'Donnell",
#   'Ibiza',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['62',
#   'Calle de Ibiza',
#   'Ibiza',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['Aparcamiento Residentes Antonio Maura',
#   'Calle Ruiz de Alarcón',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Colegio Público Palacio Valdés',
#   'Calle Almadén',
#   'Barrio de las Letras',
#   'Cortes',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Aparcamiento Residentes Espalter',
#   'Calle Espalter',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Calle de Alfonso XII',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Jardines de Herrero Palacios',
#   'Avenida de Menéndez Pelayo',
#   'Niño Jesús',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['28',
#   'Calle del Doce de Octubre',
#   'Niño Jesús',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['Parroquia de San Estanislao de Kostka',
#   '97',
#   'Calle del Doctor Esquerdo',
#   'Estrella',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['Bicimad',
#   'Plaza de los Astros',
#   'Estrella',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['Avenida de Menéndez Pelayo',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['Bicimad 75',
#   'Calle del Poeta Esteban de Villegas',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['Aparcamiento para residentes. Conde de Casal - Mediterráneo',
#   'Avenida del Mediterráneo',
#   'Niño Jesús',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['Galápago',
#   'Plaza del Conde de Casal',
#   'Pacífico',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['190',
#   'Avenida de la Ciudad de Barcelona',
#   'Adelfas',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['38',
#   'Avenida de Menéndez Pelayo',
#   'Pacífico',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['Bicimad 80B',
#   'Avenida de la Ciudad de Barcelona',
#   'Atocha',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['Bicimad 80B',
#   'Avenida de la Ciudad de Barcelona',
#   'Atocha',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['Paseo del Prado',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28014',
#   'España'],
#  ['BiciMAD',
#   'Calle de Lira',
#   'Estrella',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['Centro de Mayores "Pío Baroja"',
#   'Calle de Pío Baroja',
#   'Niño Jesús',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['191',
#   'Calle del Doctor Esquerdo',
#   'Adelfas',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['BiciMAD',
#   'Avenida de Menéndez Pelayo',
#   'Ibiza',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['Cibeles',
#   'Paseo del Prado',
#   'Jerónimos',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Residencia Santa María del Monte Carmelo',
#   'Calle de Ayala',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['75',
#   'Calle de Velázquez',
#   'Castellana',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28006',
#   'España'],
#  ['75',
#   'Calle de Ayala',
#   'Goya',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Menbur',
#   'Calle de Goya',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Tacoos',
#   '73',
#   'Calle de Hermosilla',
#   'Goya',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['51',
#   'Calle de Claudio Coello',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Plaza de Margaret Thatcher',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['94',
#   'Paseo de Recoletos',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['19',
#   'Calle de Claudio Coello',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['111',
#   'Calle de Alcalá',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['2',
#   'Avenida de Menéndez Pelayo',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['Narváez - Av. Felipe II',
#   'Avenida Felipe II',
#   'Goya',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['BiciMAD',
#   'Calle Alcántara',
#   'Goya',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28006',
#   'España'],
#  ['Volvo Servauto',
#   '99',
#   'Calle de Goya',
#   'Goya',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['34',
#   'Calle del Doctor Esquerdo',
#   'Goya',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['95',
#   'Calle de Alcalá',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Calle de José Ortega y Gasset',
#   'Castellana',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28006',
#   'España'],
#  ['Sinsombrero',
#   '4',
#   'Paseo de la Castellana',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28046',
#   'España'],
#  ['105',
#   'Acera Bici Serrano',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['106A',
#   'Acera Bici Serrano',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['32',
#   'Calle de Serrano',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Diesel',
#   'Acera Bici Serrano',
#   'Recoletos',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['108. Mártires Concepcionistas',
#   'Calle de los Mártires Concepcionistas',
#   'Goya',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['30',
#   'Calle de José Ortega y Gasset',
#   'Castellana',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Bicimad',
#   'Paseo de Moret',
#   'Casa de Campo',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Hotel Exe Moncloa',
#   '10',
#   'Calle del Arcipreste de Hita',
#   'Gaztambide',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28015',
#   'España'],
#  ['Moncloa',
#   'Calle del Arcipreste de Hita',
#   'Argüelles',
#   'Moncloa-Aravaca',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['112',
#   'Paseo de Moret',
#   'Casa de Campo',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Paseo del Pintor Rosales',
#   'Argüelles',
#   'Casa de Campo',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Centro de Especialidades Argüelles',
#   'Calle de Quintana',
#   'Argüelles',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['115',
#   'Calle de Evaristo San Miguel',
#   'Argüelles',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Pza. de España',
#   'Plaza de España',
#   'Argüelles',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28008',
#   'España'],
#  ['Bicimad 116a',
#   'Plaza de España',
#   'Argüelles',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28008',
#   'España'],
#  ['BiciMAD',
#   'Calle de Altamirano',
#   'Argüelles',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Bicimad 118',
#   'Calle de Juan Martín El Empecinado',
#   'Palos de Moguer',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['Bicimad 119',
#   'Calle de Méndez Álvaro',
#   'Atocha',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['29',
#   'Calle de Palos de la Frontera',
#   'Palos de Moguer',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['60',
#   'Paseo de Santa María de la Cabeza',
#   'Palos de Moguer',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['Apostólicas del Corazón de Jesús',
#   'Calle de José Marañón',
#   'Trafalgar',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Metropolytan',
#   '2',
#   'Calle de Guzmán el Bueno',
#   'Gaztambide',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['20',
#   'Calle de Manuel Silvela',
#   'Trafalgar',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Calle de Fernández de la Hoz',
#   'Almagro',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28010',
#   'España'],
#  ['Banca March',
#   'Calle de Eloy Gonzalo',
#   'Trafalgar',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Calle de Fernando el Católico',
#   'Arapiles',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['128',
#   'Calle de Cea Bermúdez',
#   'Gaztambide',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['La Tahona de Ponzano',
#   'Calle de José Abascal',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Carril bici Santa Engracia',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Calle de Bravo Murillo',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['BiciMAD',
#   'Calle de Santa Engracia',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['33',
#   'Calle de Raimundo Fernández Villaverde',
#   'Cuatro Caminos',
#   'Tetuán',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['BiciMAD',
#   'Calle de María de Guzmán',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Plaza de San Juan de la Cruz',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['BiciMAD',
#   'Paseo de la Castellana',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['República Argentina',
#   'Plaza de la República Argentina',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Centro de Educación Infantil del Ministerio de Fomento',
#   'Calle de Raimundo Fernández Villaverde',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['Estatua ecuestre Isabel I La Católica',
#   'Paseo de la Castellana',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['131',
#   'Calle de Velázquez',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28006',
#   'España'],
#  ['Paseo de la Castellana',
#   'Almagro',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['42',
#   'Paseo de la Castellana',
#   'Castellana',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28046',
#   'España'],
#  ['Confederación Española de Organizaciones Empresariales',
#   '50',
#   'Calle de Diego de León',
#   'Lista',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28006',
#   'España'],
#  ['BiciMAD',
#   'Calle de Juan Bravo',
#   'Lista',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['C.Est.Profes.Advos.y Lingüísticos (Cepal)',
#   'Calle de José Ortega y Gasset',
#   'Lista',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Calle María Francisca',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['45',
#   'Avenida del Doctor Arce',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28006',
#   'España'],
#  ['BiciMAD',
#   'Calle Serrano',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Buzón de Correos',
#   'Calle Santiago Bernabéu',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Paseo de la Castellana',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Crowhill Shoes',
#   'Calle de Orense',
#   'Cuatro Caminos',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['152',
#   'Avenida del General Perón',
#   'Cuatro Caminos',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Avenida del General Perón',
#   'AZCA',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['36',
#   'Calle de Orense',
#   'Cuatro Caminos',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28020',
#   'España'],
#  ['55',
#   'Calle de San Germán',
#   'Cuatro Caminos',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28020',
#   'España'],
#  ['BiciMAD',
#   'Calle de Sor Ángela de la Cruz',
#   'Castillejos',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Plaza de Cuzco',
#   'Costa Fleming',
#   'Nueva España',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['22A',
#   'Avenida de Alberto Alcocer',
#   'Hispanoamérica',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['63',
#   'Paseo de La Habana',
#   'Hispanoamérica',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['9',
#   'Calle de Colombia',
#   'Hispanoamérica',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28016',
#   'España'],
#  ['25',
#   'Paseo de la Florida',
#   'Casa de Campo',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28008',
#   'España'],
#  ['The Towers',
#   'Travesía de San Isidoro de Sevilla',
#   'Las Acacias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['BiciMAD',
#   'Paseo de la Esperanza',
#   'Las Acacias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['92',
#   'Paseo de las Delicias',
#   'Delicias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['BiciMAD',
#   'Paseo de la Chopera',
#   'Chopera',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['Viaducto de Segovia',
#   'Cuesta de Ramón',
#   'Palacio',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Bicimad Segovia 45',
#   'Calle de Segovia',
#   'Imperial',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['BiciMAD 168',
#   'Paseo de Santa María de la Cabeza',
#   'Palos de Moguer',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['Aparcabicis Escuela Infantil Municial El Alba',
#   'Calle de Toledo',
#   'Las Acacias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['BiciMAD',
#   'Paseo de la Esperanza',
#   'Las Acacias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['97',
#   'Calle de Embajadores',
#   'Delicias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['BiciMAD',
#   'Calle de Bustamante',
#   'Palos de Moguer',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['BiciMAD',
#   'Paseo de la Esperanza',
#   'Las Acacias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['Baños públicos',
#   'Paseo de Yeserías',
#   'Las Acacias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['30',
#   'Calle de Jaime I El Conquistador',
#   'Chopera',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['Garaje Plaza Legazpi',
#   'Calle de Alicante',
#   'Delicias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['3',
#   'Calle Bolívar',
#   'Legazpi',
#   'Delicias',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['3',
#   'Calle de León Gil de Palacio',
#   'Pacífico',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['BiciMAD',
#   'Calle Monte Ulía',
#   'San Diego',
#   'Puente de Vallecas',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['5',
#   'Calle de la Retama',
#   'Atocha',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['16',
#   'Calle de Ibiza',
#   'Ibiza',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['Sainz de Baranda - Juan Esplandiú',
#   'Calle del Alcalde Sáinz de Baranda',
#   'Estrella',
#   'Retiro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28007',
#   'España'],
#  ['135',
#   'Calle de Hermosilla',
#   'Goya',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28009',
#   'España'],
#  ['24',
#   'Paseo del Marqués de Zafra',
#   'Fuente del Berro',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['Calle de Sancho Dávila',
#   'Fuente del Berro',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['58',
#   'Calle del General Pardiñas',
#   'Lista',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['200',
#   'Calle de Alcalá',
#   'Fuente del Berro',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['2',
#   'Avenida de Daroca',
#   'Ventas',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Calle de la Virgen de la Alegría',
#   'Concepción',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28027',
#   'España'],
#  ['91',
#   'Calle de Velázquez',
#   'Castellana',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28006',
#   'España'],
#  ['Centro de mayores Alonso Heredia',
#   'Calle de Alonso de Heredia',
#   'Guindalera',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['MetLife',
#   'Avenida de los Toreros',
#   'Guindalera',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Avenida de los Toreros',
#   'Madrid Moderno',
#   'Guindalera',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['BiciMAD',
#   'Calle de Francisco Silvela',
#   'Guindalera',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Calle de Mataelpino',
#   'Prosperidad',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['2',
#   'Calle de Suero de Quiñones',
#   'Ciudad Jardín',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28002',
#   'España'],
#  ['69',
#   'Avenida de Concha Espina',
#   'Hispanoamérica',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['2',
#   'Plaza de Rubén Darío',
#   'Almagro',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28010',
#   'España'],
#  ['68',
#   'Calle de Fernando el Católico',
#   'Gaztambide',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28015',
#   'España'],
#  ['200',
#   'Calle de Arapiles',
#   'Arapiles',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['201',
#   'Calle de José Abascal',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Rizal',
#   'Calle de Santander',
#   'Vallehermoso',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['Parquímetro',
#   'Calle del General Ampudia',
#   'Vallehermoso',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['1',
#   'Calle del Doctor Santero',
#   'Bellas Vistas',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28039',
#   'España'],
#  ['BiciMAD',
#   'Calle Navarra',
#   'Bellas Vistas',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['L11 Marqués de Viana - Bravo Murillo',
#   'Túnel Marqués de Viana - Sor Ángela de la Cruz',
#   'Berruguete',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Calle de las Azucenas',
#   'Valdeacederas',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['208',
#   'Paseo de la Castellana',
#   'Castilla',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['209',
#   'Plaza de Castilla',
#   'Costa Fleming',
#   'Nueva España',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Brindis Pub',
#   'Calle de las Tres Cruces',
#   'Barrio de los Austrias',
#   'Sol',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28013',
#   'España'],
#  ['4',
#   'Calle del Desengaño',
#   'Malasaña',
#   'Universidad',
#   'Centro',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28004',
#   'España'],
#  ['Caixabank',
#   'Avenida Emperatriz Isabel',
#   'San Isidro',
#   'Carabanchel',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['117',
#   'Calle de Antonio López',
#   'Moscardó',
#   'Usera',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28026',
#   'España'],
#  ['Edificio Los Cubos',
#   'Calle de Albacete',
#   'San Pascual',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Centro Municipal de Mayores "Ascao"',
#   'Calle de Gutierre de Cetina',
#   'Pueblo Nuevo',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Paseo de Extremadura',
#   'Puerta del Ángel',
#   'Latina',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Ciudad Sanitaria La Paz',
#   'Calle del Arzobispo Morcillo',
#   'La Paz',
#   'Fuencarral-El Pardo',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28029',
#   'España'],
#  ['Cº Vinateros - Corr. D. Valderrabano',
#   'Calle del Camino de los Vinateros',
#   'Media Legua',
#   'Moratalaz',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28030',
#   'España'],
#  ['108',
#   'Calle del Camino de los Vinateros',
#   'Marroquina',
#   'Moratalaz',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28030',
#   'España'],
#  ['6',
#   'Calle del Arroyo de las Pilillas',
#   'Marroquina',
#   'Moratalaz',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28030',
#   'España'],
#  ['Lidl',
#   '346',
#   'Calle de la Hacienda de Pavones',
#   'Pavones',
#   'Moratalaz',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28030',
#   'España'],
#  ['Aparcabicis Madrid Río',
#   'Calle de Eugenio Caxes',
#   'Moscardó',
#   'Usera',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28026',
#   'España'],
#  ['La Plaza',
#   'Paseo de la Ermita del Santo',
#   'Cármenes',
#   'Latina',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28011',
#   'España'],
#  ['51',
#   'Calle de Caramuel',
#   'Puerta del Ángel',
#   'Latina',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Lidl',
#   '33',
#   'Calle de la Sierra Toledana',
#   'Numancia',
#   'Puente de Vallecas',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28038',
#   'España'],
#  ['86',
#   'Camino de Valderribas',
#   'Numancia',
#   'Puente de Vallecas',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28038',
#   'España'],
#  ['BiciMAD',
#   'Calle del Arroyo del Olivar',
#   'San Diego',
#   'Puente de Vallecas',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28053',
#   'España'],
#  ['BiciMad',
#   'Calle de San Delfín',
#   'Comillas',
#   'Carabanchel',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28019',
#   'España'],
#  ['Calle José del Hierro',
#   'Concepción',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28027',
#   'España'],
#  ['Calle de Carlota O’Neill',
#   'San Pascual',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['12',
#   'Calle de los Derechos Humanos',
#   'San Pascual',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28027',
#   'España'],
#  ['1',
#   'Calle de José María de Pereda',
#   'Ventas',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28017',
#   'España'],
#  ['12',
#   'Avenida del Marqués de Corbera',
#   'Ventas',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28017',
#   'España'],
#  ['Aparcabicis Metro La Elipa',
#   'Avenida del Marqués de Corbera',
#   'Ventas',
#   'Ciudad Lineal',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Calle del Sodio',
#   'Legazpi',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28045',
#   'España'],
#  ['Centro Deportivo Municipal Marqués de Samaranch',
#   '20',
#   'Paseo Imperial',
#   'Imperial',
#   'Arganzuela',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28005',
#   'España'],
#  ['237',
#   'Calle Francisco Balseiro',
#   'Bellas Vistas',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['San Germán - Poeta Joan Maragall',
#   'Calle de San Germán',
#   'Cuatro Caminos',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['62',
#   'Calle de Francos Rodríguez',
#   'Berruguete',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28039',
#   'España'],
#  ['Avenida de Brasilia',
#   'Guindalera',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['Avenida de Camilo José Cela',
#   'Guindalera',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['52',
#   'Avenida de Bruselas',
#   'Guindalera',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['Cartagena - Eraso',
#   'Calle de Cartagena',
#   'Guindalera',
#   'Salamanca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28028',
#   'España'],
#  ['44',
#   'Calle de Isaac Peral',
#   'Vallehermoso',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['63',
#   'Calle de Galileo',
#   'Arapiles',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28015',
#   'España'],
#  ['Vips',
#   'Carril bici Santa Engracia',
#   'Trafalgar',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Las Bridas',
#   'Calle de Zurbano',
#   'Ríos Rosas',
#   'Chamberí',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28003',
#   'España'],
#  ['248',
#   'Calle de Sinesio Delgado',
#   'Almenara',
#   'La Paz',
#   'Tetuán',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28029',
#   'España'],
#  ['249',
#   'Paseo de la Castellana',
#   'Castilla',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['CSIC Centro de Física Miguel A. Catalán',
#   '113',
#   'Calle de Serrano',
#   'El Viso',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Aparcabicis Ejes principales del Plan Director',
#   'Calle de Santa Hortensia',
#   'Prosperidad',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['BiciMAD',
#   'Calle de Rodríguez Jaén',
#   'Castilla',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['7',
#   'Calle Doctor Fleming',
#   'Hispanoamérica',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['La Plaza de DIA',
#   'Avenida de Alfonso XIII',
#   'Costa Fleming',
#   'Nueva España',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Ginos López Pozas',
#   '2',
#   'Calle del General López Pozas',
#   'Costa Fleming',
#   'Nueva España',
#   'Chamartín',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Beatriz de Bobadilla - Juan Montalvo',
#   'Calle Beatriz de Bobadilla',
#   'Ciudad Universitaria',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['E.T.S. Arquitectura de Madrid',
#   'Avenida Juan de Herrera',
#   'Ciudad Universitaria',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Ciudad Universitaria',
#   'Avenida de Séneca',
#   'Ciudad Universitaria',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Ciudad Universitaria',
#   'Avenida de Séneca',
#   'Ciudad Universitaria',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Ciudad Universitaria',
#   'Avenida de Séneca',
#   'Ciudad Universitaria',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España'],
#  ['Ciudad Universitaria',
#   'Avenida de Séneca',
#   'Ciudad Universitaria',
#   'Moncloa-Aravaca',
#   'Madrid',
#   'Área metropolitana de Madrid y Corredor del Henares',
#   'Comunidad de Madrid',
#   '28001',
#   'España']]

# %%
postal_codes = pd.DataFrame(postal_code, columns=['postal_code'])
postal_codes
# Out:
#     postal_code
# 0         28014
# 1         28014
# 2         28004
# 3         28001
# 4         28004
# ..          ...
# 259       28001
# 260       28001
# 261       28001
# 262       28001
# 263       28001
#
# [264 rows x 1 columns]

# %%
stations['index'] = stations.index
stations
# Out:
#                        name           longitude           latitude  \
# 0          Puerta del Sol A          -3.7018341         40.4172137
# 1          Puerta del Sol B  -3.701602938060457  40.41731271011562
# 2               Miguel Moya          -3.7058415         40.4205886
# 3        Plaza Conde Suchil          -3.7069171         40.4302937
# 4                  Malasaña          -3.7025875         40.4285524
# ..                      ...                 ...                ...
# 259                    INEF            -3.72997           40.43896
# 260  Ciudad Universitaria 1            -3.72699           40.44375
# 261  Ciudad Universitaria 2            -3.72693           40.44342
# 262       Facultad Biología          -3.7272945         40.4483322
# 263        Facultad Derecho            -3.72937           40.45109
#
#                                                address  total_bases   id  \
# 0                                  Puerta del Sol nº 1           30    1
# 1                                  Puerta del Sol nº 1           30    2
# 2                               Calle Miguel Moya nº 1           24    3
# 3             Plaza del Conde del Valle de Súchil nº 3           18    4
# 4                          Calle Manuela Malasaña nº 5           24    5
# ..                                                 ...          ...  ...
# 259  Avenida Juan de Herrera frente a la calle Paul...           24  265
# 260  Avenida de la Complutense (Metro Ciudad Univer...           24  266
# 261  Avenida de la Complutense (Metro Ciudad Univer...           24  267
# 262          Calle José Antonio Novais frente al nº 12           24  268
# 263                          Avenida Complutense nº 23           24  269
#
#     number                              location  index
# 0       1a                 40.4172137,-3.7018341      0
# 1       1b  40.41731271011562,-3.701602938060457      1
# 2        2                 40.4205886,-3.7058415      2
# 3        3                 40.4302937,-3.7069171      3
# 4        4                 40.4285524,-3.7025875      4
# ..     ...                                   ...    ...
# 259    257                     40.43896,-3.72997    259
# 260    258                     40.44375,-3.72699    260
# 261    259                     40.44342,-3.72693    261
# 262    260                 40.4483322,-3.7272945    262
# 263    261                     40.45109,-3.72937    263
#
# [264 rows x 9 columns]

# %%
postal_codes['index']=postal_codes.index
postal_codes
# Out:
#     postal_code  index
# 0         28014      0
# 1         28014      1
# 2         28004      2
# 3         28001      3
# 4         28004      4
# ..          ...    ...
# 259       28001    259
# 260       28001    260
# 261       28001    261
# 262       28001    262
# 263       28001    263
#
# [264 rows x 2 columns]

# %%
stations = stations.merge(postal_codes, on = 'index')

# %%
stations
# Out:
#                        name           longitude           latitude  \
# 0          Puerta del Sol A          -3.7018341         40.4172137
# 1          Puerta del Sol B  -3.701602938060457  40.41731271011562
# 2               Miguel Moya          -3.7058415         40.4205886
# 3        Plaza Conde Suchil          -3.7069171         40.4302937
# 4                  Malasaña          -3.7025875         40.4285524
# ..                      ...                 ...                ...
# 259                    INEF            -3.72997           40.43896
# 260  Ciudad Universitaria 1            -3.72699           40.44375
# 261  Ciudad Universitaria 2            -3.72693           40.44342
# 262       Facultad Biología          -3.7272945         40.4483322
# 263        Facultad Derecho            -3.72937           40.45109
#
#                                                address  total_bases   id  \
# 0                                  Puerta del Sol nº 1           30    1
# 1                                  Puerta del Sol nº 1           30    2
# 2                               Calle Miguel Moya nº 1           24    3
# 3             Plaza del Conde del Valle de Súchil nº 3           18    4
# 4                          Calle Manuela Malasaña nº 5           24    5
# ..                                                 ...          ...  ...
# 259  Avenida Juan de Herrera frente a la calle Paul...           24  265
# 260  Avenida de la Complutense (Metro Ciudad Univer...           24  266
# 261  Avenida de la Complutense (Metro Ciudad Univer...           24  267
# 262          Calle José Antonio Novais frente al nº 12           24  268
# 263                          Avenida Complutense nº 23           24  269
#
#     number                              location  index postal_code
# 0       1a                 40.4172137,-3.7018341      0       28014
# 1       1b  40.41731271011562,-3.701602938060457      1       28014
# 2        2                 40.4205886,-3.7058415      2       28004
# 3        3                 40.4302937,-3.7069171      3       28001
# 4        4                 40.4285524,-3.7025875      4       28004
# ..     ...                                   ...    ...         ...
# 259    257                     40.43896,-3.72997    259       28001
# 260    258                     40.44375,-3.72699    260       28001
# 261    259                     40.44342,-3.72693    261       28001
# 262    260                 40.4483322,-3.7272945    262       28001
# 263    261                     40.45109,-3.72937    263       28001
#
# [264 rows x 10 columns]

# %%
stations = stations[['id','address', 'name', 'total_bases', 'longitude', 'latitude', 'postal_code']]

# %%
stations.to_csv("all_stations.csv")

# %%
df_movements_station
# Out:
#          idunplug_station        date   weekday  hour  month  year  day  \
# 0                       1  2019-01-01   Tuesday     8      1  2019    1
# 1                       1  2019-01-01   Tuesday    11      1  2019    1
# 2                       1  2019-01-01   Tuesday    13      1  2019    1
# 3                       1  2019-01-01   Tuesday    14      1  2019    1
# 4                       1  2019-01-01   Tuesday    15      1  2019    1
# ...                   ...         ...       ...   ...    ...   ...  ...
# 2629796              2008  2020-07-23  Thursday    11      7  2020   23
# 2629797              2008  2020-08-31    Monday    20      8  2020   31
# 2629798              2008  2020-09-29   Tuesday    10      9  2020   29
# 2629799              2008  2020-12-18    Friday    12     12  2020   18
# 2629800              2008  2020-12-18    Friday    13     12  2020   18
#
#              time            datetime  rides
# 0        08:00:00 2019-01-01 08:00:00      1
# 1        11:00:00 2019-01-01 11:00:00      1
# 2        13:00:00 2019-01-01 13:00:00      1
# 3        14:00:00 2019-01-01 14:00:00      1
# 4        15:00:00 2019-01-01 15:00:00      2
# ...           ...                 ...    ...
# 2629796  11:00:00 2020-07-23 11:00:00      1
# 2629797  20:00:00 2020-08-31 20:00:00      1
# 2629798  10:00:00 2020-09-29 10:00:00      2
# 2629799  12:00:00 2020-12-18 12:00:00      1
# 2629800  13:00:00 2020-12-18 13:00:00      1
#
# [2629801 rows x 10 columns]

# %%
df_movements_station = df_movements_station.merge(stations, how='inner', left_on='idunplug_station', right_on = 'id')

# %%
df_movements_station
# Out:
#          idunplug_station        date    weekday  hour  month  year  day  \
# 0                       1  2019-01-01    Tuesday     8      1  2019    1
# 1                       1  2019-01-01    Tuesday    11      1  2019    1
# 2                       1  2019-01-01    Tuesday    13      1  2019    1
# 3                       1  2019-01-01    Tuesday    14      1  2019    1
# 4                       1  2019-01-01    Tuesday    15      1  2019    1
# ...                   ...         ...        ...   ...    ...   ...  ...
# 2629781               270  2021-06-30  Wednesday    18      6  2021   30
# 2629782               270  2021-06-30  Wednesday    19      6  2021   30
# 2629783               270  2021-06-30  Wednesday    20      6  2021   30
# 2629784               270  2021-06-30  Wednesday    21      6  2021   30
# 2629785               270  2021-06-30  Wednesday    23      6  2021   30
#
#              time            datetime  rides   id              address  \
# 0        08:00:00 2019-01-01 08:00:00      1    1  Puerta del Sol nº 1
# 1        11:00:00 2019-01-01 11:00:00      1    1  Puerta del Sol nº 1
# 2        13:00:00 2019-01-01 13:00:00      1    1  Puerta del Sol nº 1
# 3        14:00:00 2019-01-01 14:00:00      1    1  Puerta del Sol nº 1
# 4        15:00:00 2019-01-01 15:00:00      2    1  Puerta del Sol nº 1
# ...           ...                 ...    ...  ...                  ...
# 2629781  18:00:00 2021-06-30 18:00:00      4  270  Calle Zurbano nº 90
# 2629782  19:00:00 2021-06-30 19:00:00      2  270  Calle Zurbano nº 90
# 2629783  20:00:00 2021-06-30 20:00:00      2  270  Calle Zurbano nº 90
# 2629784  21:00:00 2021-06-30 21:00:00      1  270  Calle Zurbano nº 90
# 2629785  23:00:00 2021-06-30 23:00:00      1  270  Calle Zurbano nº 90
#
#                      name  total_bases   longitude    latitude postal_code
# 0        Puerta del Sol A           30  -3.7018341  40.4172137       28014
# 1        Puerta del Sol A           30  -3.7018341  40.4172137       28014
# 2        Puerta del Sol A           30  -3.7018341  40.4172137       28014
# 3        Puerta del Sol A           30  -3.7018341  40.4172137       28014
# 4        Puerta del Sol A           30  -3.7018341  40.4172137       28014
# ...                   ...          ...         ...         ...         ...
# 2629781           Zurbano           24    -3.69281    40.43837       28003
# 2629782           Zurbano           24    -3.69281    40.43837       28003
# 2629783           Zurbano           24    -3.69281    40.43837       28003
# 2629784           Zurbano           24    -3.69281    40.43837       28003
# 2629785           Zurbano           24    -3.69281    40.43837       28003
#
# [2629786 rows x 17 columns]

# %%
#We save the result in a csv that we will use for other notebooks
df_movements_station = df_movements_station.to_csv("rides_per_station.csv")
